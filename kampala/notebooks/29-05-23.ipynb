# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../..')
from modules import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jinja_df = pd.read_csv('../data/jinja_data.csv', parse_dates=['timestamp'])
jinja_df.head()
# Out:
#                   site_name  latitude  longitude   city  \
# 0  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 1  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 2  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 3  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 4  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
#
#                   timestamp  pm2_5_calibrated_value  pm2_5_raw_value  \
# 0 2021-09-01 00:00:00+00:00                     NaN              NaN
# 1 2021-09-01 01:00:00+00:00                     NaN              NaN
# 2 2021-09-01 02:00:00+00:00                     NaN              NaN
# 3 2021-09-01 03:00:00+00:00                     NaN              NaN
# 4 2021-09-01 04:00:00+00:00                     NaN              NaN
#
#    pm10_raw_value  pm10_calibrated_value                   site_id  \
# 0             NaN                    NaN  60d058c8048305120d2d6142
# 1             NaN                    NaN  60d058c8048305120d2d6142
# ...

# %%
cols = ['timestamp', 'latitude', 'longitude', 'pm2_5_calibrated_value', 'pm2_5_raw_value']
a = utils.get_device_data(jinja_df, 689753, cols)
a.head()
# Out:
#                   timestamp  latitude  longitude  pm2_5_calibrated_value  \
# 0 2021-09-01 00:00:00+00:00  0.437337  33.211051                     NaN
# 1 2021-09-01 01:00:00+00:00  0.437337  33.211051                     NaN
# 2 2021-09-01 02:00:00+00:00  0.437337  33.211051                     NaN
# 3 2021-09-01 03:00:00+00:00  0.437337  33.211051                     NaN
# 4 2021-09-01 04:00:00+00:00  0.437337  33.211051                     NaN
#
#    pm2_5_raw_value
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
type(a.iloc[0]['timestamp'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
a.isna().sum()
# Out:
# timestamp                  0
# latitude                   0
# longitude                  0
# pm2_5_calibrated_value    56
# pm2_5_raw_value           56
# dtype: int64
