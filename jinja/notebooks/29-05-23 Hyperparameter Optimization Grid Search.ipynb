# %%
import pandas as pd
import numpy as np
import sys
from math import sqrt
sys.path.append('../..')
from modules import utils
import gpflow
from gpflow import set_trainable
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jinja_df = pd.read_csv('../data/jinja_data.csv', parse_dates=['timestamp'])
jinja_df.head()
# Out:
#                   site_name  latitude  longitude   city  \
# 0  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 1  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 2  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 3  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
# 4  Jinja Main Street, Jinja  0.437337  33.211051  Jinja
#
#                   timestamp  pm2_5_calibrated_value  pm2_5_raw_value  \
# 0 2021-09-01 00:00:00+00:00                     NaN              NaN
# 1 2021-09-01 01:00:00+00:00                     NaN              NaN
# 2 2021-09-01 02:00:00+00:00                     NaN              NaN
# 3 2021-09-01 03:00:00+00:00                     NaN              NaN
# 4 2021-09-01 04:00:00+00:00                     NaN              NaN
#
#    pm10_raw_value  pm10_calibrated_value                   site_id  \
# 0             NaN                    NaN  60d058c8048305120d2d6142
# 1             NaN                    NaN  60d058c8048305120d2d6142
# 2             NaN                    NaN  60d058c8048305120d2d6142
# 3             NaN                    NaN  60d058c8048305120d2d6142
# 4             NaN                    NaN  60d058c8048305120d2d6142
#
#    device_number device_name
# 0         689753       aq_23
# 1         689753       aq_23
# 2         689753       aq_23
# 3         689753       aq_23
# 4         689753       aq_23

# %%
jinja_df.tail()
# Out:
#              site_name  latitude  longitude   city                 timestamp  \
# 16827  Mpumudde, Jinja  0.463428  33.206262  Jinja 2021-11-29 19:00:00+00:00
# 16828  Mpumudde, Jinja  0.463428  33.206262  Jinja 2021-11-29 20:00:00+00:00
# 16829  Mpumudde, Jinja  0.463428  33.206262  Jinja 2021-11-29 21:00:00+00:00
# 16830  Mpumudde, Jinja  0.463428  33.206262  Jinja 2021-11-29 22:00:00+00:00
# 16831  Mpumudde, Jinja  0.463428  33.206262  Jinja 2021-11-29 23:00:00+00:00
#
#        pm2_5_calibrated_value  pm2_5_raw_value  pm10_raw_value  \
# 16827                 37.4454        47.906395       57.335814
# 16828                 57.2599        61.122143       73.658571
# 16829                 27.6905        40.096667       48.702381
# 16830                 17.8444        32.145714       36.381786
# 16831                 18.1647        32.135000       36.750000
#
#        pm10_calibrated_value                   site_id  device_number  \
# 16827              47.493504  615c878d580358002ae96dc2        1379965
# 16828              61.470257  615c878d580358002ae96dc2        1379965
# 16829              38.925092  615c878d580358002ae96dc2        1379965
# 16830              30.198896  615c878d580358002ae96dc2        1379965
# 16831              30.314966  615c878d580358002ae96dc2        1379965
#
#       device_name
# 16827     aq_g532
# 16828     aq_g532
# 16829     aq_g532
# 16830     aq_g532
# 16831     aq_g532

# %%
latitudes = jinja_df['latitude'].unique()
longitudes = jinja_df['longitude'].unique()
device_ids = jinja_df['device_number'].unique()
len(latitudes), len(longitudes), len(device_ids)
# Out:
# (10, 10, 10)

# %%
final_df = pd.DataFrame()
cols = ['timestamp', 'latitude', 'longitude', 'pm2_5_calibrated_value']
for i, device_id in enumerate(device_ids):
    device_df = utils.get_device_data(jinja_df, device_id, cols)
    processed_df = utils.preprocessing(device_df)
    final_df = pd.concat([final_df, processed_df])
final_df.reset_index(drop=True, inplace=True)
final_df.head()
# Out:
#        time  latitude  longitude    pm2_5
# 0  452909.0  0.437337  33.211051  12.2844
# 1  452910.0  0.437337  33.211051  11.6507
# 2  452911.0  0.437337  33.211051  22.3980
# 3  452912.0  0.437337  33.211051  17.4937
# 4  452913.0  0.437337  33.211051  25.1622

# %% [markdown]
# #### The real work

# %%
lengthscales = [[0.008, 0.008, 2], None, 'train_shape']
likelihood_variances = [400, 625, None]
kernel_variances = [400, 625, None]
trainable_kernels = [False, True]
trainable_variances = [False, True]
trainable_lengthscales = [False, True]

# %%
results_df = pd.DataFrame()
count = 0
for lengthscale in lengthscales:
    for likelihood_variance in likelihood_variances:
        for kernel_variance in kernel_variances:
            for trainable_kernel in trainable_kernels:
                for trainable_variance in trainable_variances:
                    for trainable_lengthscale in trainable_lengthscales:
                        count+=1
                        rmse_list = []
                        print(f'EXPERIMENT {count}')
                        for i in range(len(latitudes)):
                            try:
                                rmse = cross_validation(final_df, i, kernel_variance, lengthscale,
                                                        likelihood_variance, trainable_kernel, trainable_variance,
                                                        trainable_lengthscale)
                                rmse_list.append(rmse)
                                print(f'{device_ids[i]} successful')
                            except Exception as e:
                                print(e)
                                print(f'{device_ids[i]} failed')
                            
                        mean_rmse = np.mean(rmse_list)
                        results_dict= {'lengthscale':lengthscale, 'likelihood_variance':likelihood_variance, 
                                       'kernel_variance':kernel_variance, 'trainable_kernel':trainable_kernel, 
                                       'trainable_variance':trainable_variance, 
                                       'trainable_lengthscale':trainable_lengthscale, 'avg_rmse':mean_rmse, 
                                       'rmse_list':rmse_list}
                        print(results_dict)
                        results_df = results_df.append(results_dict, ignore_index=True)
                        results_df.to_csv(f'../results/basic_results_{count}.csv', index=False)
# Out:
# EXPERIMENT 1
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\envs\gp_env\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.494394716616823, 'rmse_list': [9.197245008922383, 21.38619316947233, 12.899745971455749]}
# EXPERIMENT 2
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.09476851187678, 'rmse_list': [13.707817552141956, 19.360463598358283, 12.216024385130098]}
# EXPERIMENT 3
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 13.585488564125455, 'rmse_list': [9.197225558929107, 19.341747542739817, 12.21749259070744]}
# EXPERIMENT 4
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.11122940027712, 'rmse_list': [13.67205310083204, 19.42875650248158, 12.232878597517741]}
# EXPERIMENT 5
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.460013421668775, 'rmse_list': [9.19698663456346, 23.362888695192172, 13.820164935250686]}
# EXPERIMENT 6
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.540436898113148, 'rmse_list': [9.176443707835897, 23.479130178703834, 13.965736807799711]}
# EXPERIMENT 7
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.449004347033076, 'rmse_list': [9.082392243451524, 21.369443246822044, 12.895177550825668]}
# EXPERIMENT 8
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.377705151363903, 'rmse_list': [9.01891118355971, 21.25555614140996, 12.858648129122036]}
# EXPERIMENT 9
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 16.481413920049075, 'rmse_list': [15.158119646581378, 21.386374034170704, 12.899748079395147]}
# EXPERIMENT 10
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094773110289049, 'rmse_list': [13.707831472177853, 19.360463635614526, 12.216024223074767]}
# EXPERIMENT 11
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.559813706521533, 'rmse_list': [15.125110527617476, 19.34143294577413, 12.212897646172994]}
# EXPERIMENT 12
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.1112773738501, 'rmse_list': [13.672200918315928, 19.428754012985195, 12.232877190249175]}
# EXPERIMENT 13
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 16.82008300897385, 'rmse_list': [16.028148346123213, 21.398335516743728, 13.033765164054605]}
# EXPERIMENT 14
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.101475786466317, 'rmse_list': [13.699488182884709, 19.361354078259634, 12.243585098254604]}
# EXPERIMENT 15
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.847430932837995, 'rmse_list': [16.015094656250824, 19.289733406733998, 12.237464735529157]}
# EXPERIMENT 16
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.095628962252057, 'rmse_list': [13.671440317089651, 19.36973104583507, 12.245715523831452]}
# EXPERIMENT 17
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 60.670869590551575, 'rmse_list': [15.15787240758529, 23.260607027311046, 143.59412933675839]}
# EXPERIMENT 18
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094773107179188, 'rmse_list': [13.707831533095062, 19.360463592008735, 12.216024196433768]}
# EXPERIMENT 19
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.559927652059239, 'rmse_list': [15.125632194361957, 19.34142096581468, 12.212729796001078]}
# EXPERIMENT 20
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.11123186140196, 'rmse_list': [13.672062343580718, 19.428755982310676, 12.23287725831448]}
# EXPERIMENT 21
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 17.97881987312609, 'rmse_list': [18.16800996382953, 22.67640385556426, 13.092045799984472]}
# EXPERIMENT 22
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.10095032723351, 'rmse_list': [13.683746857884584, 19.361771512523525, 12.257332611292417]}
# EXPERIMENT 23
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 16.571771822956304, 'rmse_list': [18.167905553529348, 19.28885339814336, 12.258556517196206]}
# EXPERIMENT 24
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.096816760237395, 'rmse_list': [13.663788059217845, 19.367773369570443, 12.2588888519239]}
# EXPERIMENT 25
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.594641057689678, 'rmse_list': [9.197229061039794, 23.570095120900536, 14.016598991128703]}
# EXPERIMENT 26
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 17.098144709477555, 'rmse_list': [13.707736998505732, 23.57009686258952, 14.016600267337418]}
# EXPERIMENT 27
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.627270537162966, 'rmse_list': [9.17921107252341, 23.636560934641636, 14.066039604323855]}
# EXPERIMENT 28
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.627270514678449, 'rmse_list': [9.179211071410053, 23.636560876396217, 14.066039596229077]}
# EXPERIMENT 29
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.460083813500495, 'rmse_list': [9.197198540327426, 23.362891068026396, 13.820161832147658]}
# EXPERIMENT 30
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.540521155372325, 'rmse_list': [9.176712226719962, 23.47912109431149, 13.965730145085525]}
# EXPERIMENT 31
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.617460840189006, 'rmse_list': [9.182574004268243, 23.611509477443573, 14.0582990388552]}
# EXPERIMENT 32
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.615581564959557, 'rmse_list': [9.162819889947928, 23.6245549640626, 14.059369840868142]}
# EXPERIMENT 33
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 56.62022372307729, 'rmse_list': [9.199802404718001, 23.24415631285785, 137.41671245165602]}
# EXPERIMENT 34
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094755703584545, 'rmse_list': [13.70778697718472, 19.36046362860717, 12.216016504961742]}
# EXPERIMENT 35
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.735106506141825, 'rmse_list': [9.201139020675136, 23.453813315546242, 14.550367182204097]}
# EXPERIMENT 36
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626936685559734, 'rmse_list': [9.179307541525517, 23.635935085217078, 14.065567429936609]}
# EXPERIMENT 37
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 59.33500641377705, 'rmse_list': [9.17225008092676, 23.247502460100986, 145.5852667003034]}
# EXPERIMENT 38
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.101337099124232, 'rmse_list': [13.699468838005442, 19.361342056853147, 12.243200402514104]}
# EXPERIMENT 39
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.696445225422247, 'rmse_list': [9.154270903896206, 23.441732230886927, 14.493332541483609]}
# EXPERIMENT 40
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.38419808585562, 'rmse_list': [8.857066062552436, 21.34285779416416, 12.952670400850268]}
# EXPERIMENT 41
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 66.92301534469105, 'rmse_list': [9.197621231727865, 23.25453557437908, 168.31688922796621]}
# EXPERIMENT 42
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094770423705524, 'rmse_list': [13.70783826970332, 19.360465347592818, 12.216007653820434]}
# EXPERIMENT 43
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.729285657140208, 'rmse_list': [9.180448788580025, 23.452550634429652, 14.554857548410945]}
# EXPERIMENT 44
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626922782897807, 'rmse_list': [9.178964203351956, 23.636107012680547, 14.065697132660913]}
# EXPERIMENT 45
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 73.74103415882432, 'rmse_list': [9.18979505600344, 23.23102507789217, 188.80228234257734]}
# EXPERIMENT 46
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.100719525859406, 'rmse_list': [13.683365793522112, 19.361762378788832, 12.257030405267272]}
# EXPERIMENT 47
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.685146961058523, 'rmse_list': [9.219195147435691, 23.420995882141654, 14.415249853598224]}
# EXPERIMENT 48
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.410181179217764, 'rmse_list': [9.409803243944287, 20.996411203909506, 12.8243290897995]}
# EXPERIMENT 49
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.594653736797595, 'rmse_list': [9.197269458809183, 23.57009375931784, 14.01659799226576]}
# EXPERIMENT 50
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 17.098181636255514, 'rmse_list': [13.70784995555286, 23.570095606919587, 14.01659934629409]}
# EXPERIMENT 51
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.634690528069248, 'rmse_list': [9.144940900634925, 23.66868820062335, 14.090442482949474]}
# EXPERIMENT 52
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634690484121515, 'rmse_list': [9.144940813988022, 23.668688144888844, 14.09044249348769]}
# EXPERIMENT 53
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.495743875998068, 'rmse_list': [9.304178143722416, 23.362891169380234, 13.820162314891553]}
# EXPERIMENT 54
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.540363560399486, 'rmse_list': [9.176236859835475, 23.479122703339705, 13.96573111802328]}
# EXPERIMENT 55
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.630855814499862, 'rmse_list': [9.147980037966729, 23.655650701263035, 14.088936704269823]}
# EXPERIMENT 56
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626381124427288, 'rmse_list': [9.133205296137909, 23.660193046166572, 14.085745030977375]}
# EXPERIMENT 57
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 57.995259967574036, 'rmse_list': [9.197267765331313, 23.242543305702572, 141.5459688316882]}
# EXPERIMENT 58
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 17.09811369264797, 'rmse_list': [13.707642977413828, 23.57009742317862, 14.016600677351459]}
# EXPERIMENT 59
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.603345825103093, 'rmse_list': [9.144529742991068, 23.594988677516927, 14.070519054801288]}
# EXPERIMENT 60
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634519392478822, 'rmse_list': [9.14568437368208, 23.66797582966214, 14.089897974092244]}
# EXPERIMENT 61
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 61.00842139150624, 'rmse_list': [9.197253595285831, 23.248279657351045, 150.57973092188183]}
# EXPERIMENT 62
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.101427419367461, 'rmse_list': [13.699666103862437, 19.361344271497604, 12.24327188274234]}
# EXPERIMENT 63
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.601807336567807, 'rmse_list': [9.167464240589437, 23.566659825578956, 14.071297943535033]}
# EXPERIMENT 64
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.422417461838618, 'rmse_list': [8.39356423565931, 21.73682246751165, 13.136865682344888]}
# EXPERIMENT 65
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 671.8124613421278, 'rmse_list': [9.205981920114667, 23.52750446505021, 1982.7038976412184]}
# EXPERIMENT 66
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094771409637625, 'rmse_list': [13.707833184317124, 19.360463371449026, 12.216017673146721]}
# EXPERIMENT 67
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.6140878460043, 'rmse_list': [9.168876543676646, 23.587783973914167, 14.085603020422088]}
# EXPERIMENT 68
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634767077128899, 'rmse_list': [9.146324721056581, 23.668034043447093, 14.089942466883022]}
# EXPERIMENT 69
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 64.4933647944088, 'rmse_list': [9.21716274985707, 23.283477347505226, 160.9794542858641]}
# EXPERIMENT 70
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.100784933902238, 'rmse_list': [13.683544890073307, 19.36176287479531, 12.257047036838092]}
# EXPERIMENT 71
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.573483379490531, 'rmse_list': [9.153519182808184, 23.54669350900647, 14.020237446656935]}
# EXPERIMENT 72
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': None, 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.388932313425704, 'rmse_list': [8.793171581547716, 21.379140028201643, 12.99448533052775]}
# EXPERIMENT 73
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.858071801872782, 'rmse_list': [8.656917646810474, 22.516110008994783, 13.401187749813094]}
# EXPERIMENT 74
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.858071801872782, 'rmse_list': [8.656917646810474, 22.516110008994783, 13.401187749813094]}
# EXPERIMENT 75
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.658187301100503, 'rmse_list': [9.476855735150055, 21.5684054853013, 12.92930068285015]}
# EXPERIMENT 76
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.658187301100503, 'rmse_list': [9.476855735150055, 21.5684054853013, 12.92930068285015]}
# EXPERIMENT 77
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.571489954594606, 'rmse_list': [9.189856378635861, 23.531751859923066, 13.992861625224892]}
# EXPERIMENT 78
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.571489954594606, 'rmse_list': [9.189856378635861, 23.531751859923066, 13.992861625224892]}
# EXPERIMENT 79
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.875382060239636, 'rmse_list': [8.723378138313421, 22.507838635894068, 13.394929406511414]}
# EXPERIMENT 80
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.875382060239636, 'rmse_list': [8.723378138313421, 22.507838635894068, 13.394929406511414]}
# EXPERIMENT 81
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.64508360414557, 'rmse_list': [9.485638452291663, 21.535129492087208, 12.914482868057844]}
# EXPERIMENT 82
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.64508360414557, 'rmse_list': [9.485638452291663, 21.535129492087208, 12.914482868057844]}
# EXPERIMENT 83
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.658261611556782, 'rmse_list': [9.477079636959873, 21.568404927236674, 12.929300270473796]}
# EXPERIMENT 84
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.658261611556782, 'rmse_list': [9.477079636959873, 21.568404927236674, 12.929300270473796]}
# EXPERIMENT 85
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.667927521368533, 'rmse_list': [9.47061109748772, 21.580732333633318, 12.95243913298456]}
# EXPERIMENT 86
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.667927521368533, 'rmse_list': [9.47061109748772, 21.580732333633318, 12.95243913298456]}
# EXPERIMENT 87
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.667842695698118, 'rmse_list': [9.463663965709076, 21.585331611541026, 12.954532509844245]}
# EXPERIMENT 88
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.667842695698118, 'rmse_list': [9.463663965709076, 21.585331611541026, 12.954532509844245]}
# EXPERIMENT 89
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.644920611137971, 'rmse_list': [9.485153792821414, 21.53512711292243, 12.914480927670068]}
# EXPERIMENT 90
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.644920611137971, 'rmse_list': [9.485153792821414, 21.53512711292243, 12.914480927670068]}
# EXPERIMENT 91
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.658128129135187, 'rmse_list': [9.476685697796876, 21.568401392227678, 12.929297297381009]}
# EXPERIMENT 92
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.658128129135187, 'rmse_list': [9.476685697796876, 21.568401392227678, 12.929297297381009]}
# EXPERIMENT 93
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.671995422548989, 'rmse_list': [9.441961054028043, 21.6027522239969, 12.971272989622019]}
# EXPERIMENT 94
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.671995422548989, 'rmse_list': [9.441961054028043, 21.6027522239969, 12.971272989622019]}
# EXPERIMENT 95
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.671943274418531, 'rmse_list': [9.436960799676084, 21.606069017345796, 12.972800006233713]}
# EXPERIMENT 96
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': None, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.671943274418531, 'rmse_list': [9.436960799676084, 21.606069017345796, 12.972800006233713]}
# EXPERIMENT 97
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.594629228712806, 'rmse_list': [9.197192741522338, 23.57009560113042, 14.016599343485666]}
# EXPERIMENT 98
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.594629228712806, 'rmse_list': [9.197192741522338, 23.57009560113042, 14.016599343485666]}
# EXPERIMENT 99
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.627270649857358, 'rmse_list': [9.179210192257944, 23.636561617708672, 14.066040139605454]}
# EXPERIMENT 100
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.627270649857358, 'rmse_list': [9.179210192257944, 23.636561617708672, 14.066040139605454]}
# EXPERIMENT 101
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.571578908057317, 'rmse_list': [9.19012410232012, 23.53175137060368, 13.992861251248152]}
# EXPERIMENT 102
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.571578908057317, 'rmse_list': [9.19012410232012, 23.53175137060368, 13.992861251248152]}
# EXPERIMENT 103
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.622663452146206, 'rmse_list': [9.173406146557669, 23.631597518767666, 14.062986691113279]}
# EXPERIMENT 104
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.622663452146206, 'rmse_list': [9.173406146557669, 23.631597518767666, 14.062986691113279]}
# EXPERIMENT 105
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.858072439074112, 'rmse_list': [8.656923345956304, 22.516107702792425, 13.401186268473607]}
# EXPERIMENT 106
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.858072439074112, 'rmse_list': [8.656923345956304, 22.516107702792425, 13.401186268473607]}
# EXPERIMENT 107
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.627269414301823, 'rmse_list': [9.179278763603593, 23.636520427337516, 14.066009051964365]}
# EXPERIMENT 108
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.627269414301823, 'rmse_list': [9.179278763603593, 23.636520427337516, 14.066009051964365]}
# EXPERIMENT 109
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.667929187944935, 'rmse_list': [9.470668412454673, 21.580704014726553, 12.952415136653581]}
# EXPERIMENT 110
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.667929187944935, 'rmse_list': [9.470668412454673, 21.580704014726553, 12.952415136653581]}
# EXPERIMENT 111
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.897535282215756, 'rmse_list': [8.555686258757365, 22.639058445704176, 13.497861142185723]}
# EXPERIMENT 112
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.897535282215756, 'rmse_list': [8.555686258757365, 22.639058445704176, 13.497861142185723]}
# EXPERIMENT 113
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.460719962017693, 'rmse_list': [8.92880312374991, 21.537710212732183, 12.915646549570987]}
# EXPERIMENT 114
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.460719962017693, 'rmse_list': [8.92880312374991, 21.537710212732183, 12.915646549570987]}
# EXPERIMENT 115
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.626907274206689, 'rmse_list': [9.178457042699524, 23.636369561644763, 14.065895218275775]}
# EXPERIMENT 116
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626907274206689, 'rmse_list': [9.178457042699524, 23.636369561644763, 14.065895218275775]}
# EXPERIMENT 117
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.671600359447268, 'rmse_list': [9.441237853036052, 21.602504161850174, 12.971059063455579]}
# EXPERIMENT 118
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.671600359447268, 'rmse_list': [9.441237853036052, 21.602504161850174, 12.971059063455579]}
# EXPERIMENT 119
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.828708728492487, 'rmse_list': [8.57152810951105, 22.489203277367153, 13.425394798599257]}
# EXPERIMENT 120
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.828708728492487, 'rmse_list': [8.57152810951105, 22.489203277367153, 13.425394798599257]}
# EXPERIMENT 121
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.594499156385474, 'rmse_list': [9.196806929337153, 23.57009306003109, 14.016597479788182]}
# EXPERIMENT 122
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.594499156385474, 'rmse_list': [9.196806929337153, 23.57009306003109, 14.016597479788182]}
# EXPERIMENT 123
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.634690739335504, 'rmse_list': [9.144939410498765, 23.66868938452345, 14.0904434229843]}
# EXPERIMENT 124
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634690739335504, 'rmse_list': [9.144939410498765, 23.66868938452345, 14.0904434229843]}
# EXPERIMENT 125
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.57141856025992, 'rmse_list': [9.189653022937602, 23.53174560200567, 13.992857055836478]}
# EXPERIMENT 126
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.57141856025992, 'rmse_list': [9.189653022937602, 23.53174560200567, 13.992857055836478]}
# EXPERIMENT 127
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.631426867622713, 'rmse_list': [9.140754989987474, 23.665211761783723, 14.088313851096945]}
# EXPERIMENT 128
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.631426867622713, 'rmse_list': [9.140754989987474, 23.665211761783723, 14.088313851096945]}
# EXPERIMENT 129
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.45057603763753, 'rmse_list': [8.769632595836566, 23.56725146997902, 14.014844047097009]}
# EXPERIMENT 130
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.45057603763753, 'rmse_list': [8.769632595836566, 23.56725146997902, 14.014844047097009]}
# EXPERIMENT 131
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.63418958475352, 'rmse_list': [9.144074555081874, 23.668327459074465, 14.090166740104213]}
# EXPERIMENT 132
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.63418958475352, 'rmse_list': [9.144074555081874, 23.668327459074465, 14.090166740104213]}
# EXPERIMENT 133
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.667636547625845, 'rmse_list': [9.469981635203975, 21.58060057861421, 12.952327429059347]}
# EXPERIMENT 134
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.667636547625845, 'rmse_list': [9.469981635203975, 21.58060057861421, 12.952327429059347]}
# EXPERIMENT 135
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 14.993600816502136, 'rmse_list': [8.514362461077209, 22.846721837834806, 13.61971815059439]}
# EXPERIMENT 136
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.993600816502136, 'rmse_list': [8.514362461077209, 22.846721837834806, 13.61971815059439]}
# EXPERIMENT 137
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 14.85808011194444, 'rmse_list': [8.656943559828205, 22.516109297644938, 13.40118747836018]}
# EXPERIMENT 138
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': [0.008, 0.008, 2], 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 14.85808011194444, 'rmse_list': [8.656943559828205, 22.516109297644938, 13.40118747836018]}
# EXPERIMENT 139
# 689753 successful
# 1014698 successful
# 1014692 successful
# ...
# EXPERIMENT 171
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.627270522746892, 'rmse_list': [9.179211071069615, 23.63656089857811, 14.066039598592951]}
# EXPERIMENT 172
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.627270514678449, 'rmse_list': [9.179211071410053, 23.636560876396217, 14.066039596229077]}
# EXPERIMENT 173
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.456211726612182, 'rmse_list': [9.185526782176682, 23.362939866540508, 13.820168531119357]}
# EXPERIMENT 174
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.540521155372325, 'rmse_list': [9.176712226719962, 23.47912109431149, 13.965730145085525]}
# EXPERIMENT 175
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.617862112825456, 'rmse_list': [9.183766162633404, 23.61152033729432, 14.058299838548642]}
# EXPERIMENT 176
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.615581564959557, 'rmse_list': [9.162819889947928, 23.6245549640626, 14.059369840868142]}
# EXPERIMENT 177
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 56.930208265846865, 'rmse_list': [9.197108206608249, 23.23728100302904, 138.3562355879033]}
# EXPERIMENT 178
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094755703584545, 'rmse_list': [13.70778697718472, 19.36046362860717, 12.216016504961742]}
# EXPERIMENT 179
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.73462537675104, 'rmse_list': [9.197632414958676, 23.45557216562748, 14.550671549666964]}
# EXPERIMENT 180
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626936685559734, 'rmse_list': [9.179307541525517, 23.635935085217078, 14.065567429936609]}
# EXPERIMENT 181
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 57.73274448839481, 'rmse_list': [9.168787777984303, 23.256687718281295, 140.77275796891882]}
# EXPERIMENT 182
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.101337099124232, 'rmse_list': [13.699468838005442, 19.361342056853147, 12.243200402514104]}
# EXPERIMENT 183
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.695979570649763, 'rmse_list': [9.150814444357628, 23.44348793464609, 14.493636332945568]}
# EXPERIMENT 184
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.38419808585562, 'rmse_list': [8.857066062552436, 21.34285779416416, 12.952670400850268]}
# EXPERIMENT 185
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 16.14629098565977, 'rmse_list': [9.197621132212067, 23.165579479598684, 16.075672345168552]}
# EXPERIMENT 186
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094770423705524, 'rmse_list': [13.70783826970332, 19.360465347592818, 12.216007653820434]}
# EXPERIMENT 187
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.729973162443196, 'rmse_list': [9.180448074130659, 23.45430947981477, 14.55516193338416]}
# EXPERIMENT 188
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626922782897807, 'rmse_list': [9.178964203351956, 23.636107012680547, 14.065697132660913]}
# EXPERIMENT 189
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 74.24354536073939, 'rmse_list': [9.186281735052527, 23.24728496781493, 190.29706937935072]}
# EXPERIMENT 190
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.100719525859406, 'rmse_list': [13.683365793522112, 19.361762378788832, 12.257030405267272]}
# EXPERIMENT 191
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.68479573232763, 'rmse_list': [9.216088134715429, 23.42274671712356, 14.415552345143908]}
# EXPERIMENT 192
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 425, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.410181179217764, 'rmse_list': [9.409803243944287, 20.996411203909506, 12.8243290897995]}
# EXPERIMENT 193
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.579852217452958, 'rmse_list': [9.15286490166517, 23.570093758804287, 14.016597991889409]}
# EXPERIMENT 194
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 17.098181636255514, 'rmse_list': [13.70784995555286, 23.570095606919587, 14.01659934629409]}
# EXPERIMENT 195
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.634690189953597, 'rmse_list': [9.144939986504514, 23.668688121458217, 14.09044246189806]}
# EXPERIMENT 196
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634690484121515, 'rmse_list': [9.144940813988022, 23.668688144888844, 14.09044249348769]}
# EXPERIMENT 197
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 15.49576569519578, 'rmse_list': [9.304188985387452, 23.362939441943986, 13.820168658255911]}
# EXPERIMENT 198
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.540363560399486, 'rmse_list': [9.176236859835475, 23.479122703339705, 13.96573111802328]}
# EXPERIMENT 199
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.630855506243387, 'rmse_list': [9.147970933997376, 23.655658328011604, 14.088937256721184]}
# EXPERIMENT 200
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': None, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.626381124427288, 'rmse_list': [9.133205296137909, 23.660193046166572, 14.085745030977375]}
# EXPERIMENT 201
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 58.63215794581339, 'rmse_list': [9.197267711348148, 23.241754275469876, 143.45745185062214]}
# EXPERIMENT 202
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 17.09811369264797, 'rmse_list': [13.707642977413828, 23.57009742317862, 14.016600677351459]}
# EXPERIMENT 203
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.60401736343414, 'rmse_list': [9.144529710030938, 23.59673566578142, 14.07078671449006]}
# EXPERIMENT 204
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634519392478822, 'rmse_list': [9.14568437368208, 23.66797582966214, 14.089897974092244]}
# EXPERIMENT 205
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 61.074738660451516, 'rmse_list': [9.197296332494009, 23.249203407302506, 150.77771624155804]}
# EXPERIMENT 206
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.101427419367461, 'rmse_list': [13.699666103862437, 19.361344271497604, 12.24327188274234]}
# EXPERIMENT 207
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.601760330203673, 'rmse_list': [9.16530650924436, 23.568404658176654, 14.071569823190005]}
# EXPERIMENT 208
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 425, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.422417461838618, 'rmse_list': [8.39356423565931, 21.73682246751165, 13.136865682344888]}
# EXPERIMENT 209
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 60.48655730404289, 'rmse_list': [9.202480631715781, 23.23876696947418, 149.0184243109387]}
# EXPERIMENT 210
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.094771409637625, 'rmse_list': [13.707833184317124, 19.360463371449026, 12.216017673146721]}
# EXPERIMENT 211
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.61359695378207, 'rmse_list': [9.165383193778197, 23.58953237852017, 14.085875289047841]}
# EXPERIMENT 212
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': True, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 15.634767077128899, 'rmse_list': [9.146324721056581, 23.668034043447093, 14.089942466883022]}
# EXPERIMENT 213
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': True, 'avg_rmse': 598.1463928254383, 'rmse_list': [9.203256192765922, 23.387681433322296, 1761.8482408502268]}
# EXPERIMENT 214
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': True, 'trainable_lengthscale': False, 'avg_rmse': 15.100784933902238, 'rmse_list': [13.683544890073307, 19.36176287479531, 12.257047036838092]}
# EXPERIMENT 215
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': True, 'avg_rmse': 15.5729944363112, 'rmse_list': [9.150054433356287, 23.54842966976711, 14.0204992058102]}
# EXPERIMENT 216
# 689753 successful
# 1014698 successful
# 1014692 successful
# {'lengthscale': 'train_shape', 'likelihood_variance': 600, 'kernel_variance': 600, 'trainable_kernel': False, 'trainable_variance': False, 'trainable_lengthscale': False, 'avg_rmse': 14.388932313425704, 'rmse_list': [8.793171581547716, 21.379140028201643, 12.99448533052775]}

# %%
results = pd.read_csv('../results/basic_results.csv')
results
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12096\2423329655.py in <module>
# ----> 1 results = pd.read_csv('../results/hyperparameter_results.csv')
#       2 results
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\anaconda3\envs\gp_env\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/hyperparameter_results.csv'
